# %%
# import libraries 
import numpy as np
import pandas as pd
import re
import math

# %%
# show full dataframe infomation
pd.set_option('display.max_colwidth', None)

# %%
# convert xlsx into dataframe, remove first row and headers
df = pd.read_excel("NZ_Admin_JOBS.xlsx", skiprows = 1, header=None)

# %%
# column 3 replace empty cells with N/A
df.fillna('N/A', inplace=True)

# %%
df
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                               1  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...

# %%
# check column 3 info before modification
df[3].head(40)
# Out:
# 0                                               location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 1                                               location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 2                                                                               location: AucklandAuckland
# 3                                               location: SouthlandSouthlandarea: InvercargillInvercargill
# 4                                             location: CanterburyCanterburyarea: ChristchurchChristchurch
# 5                                                     location: NorthlandNorthlandarea: WhangareiWhangarei
# 6                                 location: WellingtonWellingtonarea: Wellington CentralWellington Central
# 7                                                 location: Bay of PlentyBay of Plentyarea: RotoruaRotorua
# 8                                               location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# ...

# %%
# split location and area infomation into two different columns 
# remove all none infomation related items 
df[['location','area']] = df[3].str.split('area:', expand=True)
df['location'] = df['location'].str.replace('location:','')
df['location'].fillna('N/A', inplace=True)
df['area'].fillna('N/A', inplace=True)

# %%
# create a split string function to extract non-duplicated word 
def split_string(text):
    for i in range(1, len(text)-1):
        if text[i].isupper() and text[i-1].islower():
            return text[:i]
    return text

# %%
df['area'] = df['area'].apply(split_string)

# %%
df['location'] = df['location'].apply(split_string)

# %%
df
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                               1  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...

# %%
# standardize units for column 4
df['duration'] = df[4][df[4].str.contains(r'\d')]

# %%
df['duration'].fillna('N/A', inplace=True)

# %%
df['duration'] = df['duration'].apply(lambda x: x.split()[0])

# %%
def unit_convertion (text):
    if text != 'N/A':
        unit_pattern = r"\d([a-z])"
        digit_pattern = r"\d"
        unit = re.findall(unit_pattern, text)[0]
        digit = re.findall(digit_pattern, text)[0]
        digit = int(digit)
        if unit == 'h':
            output = 0
            return output
        elif unit == 'm':
            output = digit * 30
            return output
        else:
            return digit
    else:
        return 'N/A'

# %%
df['duration'] = df['duration'].apply(unit_convertion)

# %%
df
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                               1  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...

# %%
# two types of salaries, 1. Hourly rate and 2. Annual rate

# %%
# First, we extract numerical values only 
df[df[5].str.contains('\d',na=False)][5].head(50)
# Out:
# 12                             $20 per hour
# 17                    $20 - $24.99 per hour
# 23                      $19 to $22 per hour
# 25                    $20 - $24.99 per hour
# 36                    $20 - $24.99 per hour
# 42                        $40,000 - $49,999
# 48                             $25 per hour
# 58              $60 000 - $70 000 per annum
# 59                          $20.00 per hour
# 66                    $20 - $24.99 per hour
# 75                        $55,000 - $69,999
# 77                         $20.00 per hour.
# 78                    $20 - $24.99 per hour
# 81                             $21 per hour
# 82                        $55,000 - $64,999
# 89          $50,000 - $55,000 plus benefits
# 97                        $45,000 - $49,999
# 103    $55,000 - $60,000 per annum pro rata
# 112                   $20 - $24.99 per hour
# 114                   $20 - $24.99 per hour
# 123                       $48,835 - $63,221
# ...

# %%
# replace value containing k 
df[df[5].str.contains('\dk',na=False)][5]
# Out:
# 306                                       $75k - $85k p.a.
# 442                     $60k-$70k depending on experience!
# 473     $60 - $65k + Career Progression to QS / leadership
# 644                      $50k - $65k p.a. + plus kiwisaver
# 650                                         $70-$80k+Super
# 663                                      $70-75k per annum
# 695                                              Circa 50k
# 1949                                             Circa 50k
# Name: 5, dtype: object

# %%
# loop through cells and multiply by 1000 if k is present
for index, salary in enumerate(df[5]):
    salary = str(salary)
    if 'k' in salary:
        pattern = r'\$?(\d+[\dk]+)'
        matches = re.findall(pattern, salary)
        for match in matches:
            if 'k' in match:
                match = match.replace('k','')
            match = float(match)
            match = match * 1000
            match = str(match)
            df.at[index,5] = match

# %%
# replace 'to' with '-'
df[5] = df[df[5].str.contains('\d',na=False)][5].str.replace(' to ','-', regex=True)

# %%
# This can be ignored or time 8% into the min and max salary
df[df[5].str.contains('\d\%',na=False)][5].head(100)
# Out:
# 201                        8% holiday pay
# 311           $24 - $25 + 8% holiday pay!
# 384       $30 - $38 p.h. + 8% Holiday Pay
# 403        Up-$23 p.h. + + 8% Holiday Pay
# 458       $27 - $33 p.h. + 8% holiday pay
# 503          Up-$27 p.h. + 8% Holiday Pay
# 536       $21 - $25 p.h. + 8% Holiday Pay
# 578          Up-$35 p.h. + 8% Holiday Pay
# 579       $21 - $22 p.h. + 8% Holiday Pay
# 682      $24 - $28 p.h.  + 8% Holiday Pay
# 683     $35 - $40 p.h. + + 8% Holiday Pay
# 1936     $24 - $28 p.h.  + 8% Holiday Pay
# 1937    $35 - $40 p.h. + + 8% Holiday Pay
# Name: 5, dtype: object

# %%
# split and select from the n=1 
df[['min_salary','max_salary']] = df[5].str.split('-', n=1, expand = True).fillna('unknown')

# %%
df[df['min_salary'].str.contains('\d',na=False)][[5,'min_salary','max_salary']].head(50)
# Out:
#                                                  5          min_salary  \
# 12                                    $20 per hour        $20 per hour
# 17                           $20 - $24.99 per hour                $20
# 23                                $19-$22 per hour                 $19
# 25                           $20 - $24.99 per hour                $20
# 36                           $20 - $24.99 per hour                $20
# 42                               $40,000 - $49,999            $40,000
# 48                                    $25 per hour        $25 per hour
# 58                     $60 000 - $70 000 per annum            $60 000
# 59                                 $20.00 per hour     $20.00 per hour
# 66                           $20 - $24.99 per hour                $20
# 75                               $55,000 - $69,999            $55,000
# 77                                $20.00 per hour.    $20.00 per hour.
# ...

# %%
df[df['max_salary'].str.contains('\d',na=False)]['max_salary'].head(50)
# Out:
# 17                               $24.99 per hour
# 23                                  $22 per hour
# 25                               $24.99 per hour
# 36                               $24.99 per hour
# 42                                       $49,999
# 58                             $70 000 per annum
# 66                               $24.99 per hour
# 75                                       $69,999
# 78                               $24.99 per hour
# 82                                       $64,999
# 89                         $55,000 plus benefits
# 97                                       $49,999
# 103                   $60,000 per annum pro rata
# 112                              $24.99 per hour
# 114                              $24.99 per hour
# 123                                      $63,221
# 134                              $29.99 per hour
# 148                                          $28
# 156                                        $27ph
# ...

# %%
# extract data and clean unnessacery info
df['min_salary'] = df['min_salary'].str.extract('(\d+\.\d+|\d+ \d+|\d+k|\d+)')
df['max_salary'] = df['max_salary'].str.extract('(\d+\.\d+|\d+ \d+|\d+k|\d+)')

# %%
df[df['min_salary'].str.contains('\d', na=False)]['min_salary'].head(100)
# Out:
# 12           20
# 17           20
# 23           19
# 25           20
# 36           20
#          ...
# 683          35
# 695     50000.0
# 1936         24
# 1937         35
# 1949    50000.0
# Name: min_salary, Length: 91, dtype: object

# %%
df['min_salary'] = df[df['min_salary'].str.contains('\d', na=False)]['min_salary'].str.replace(' ','',regex=True)
df['max_salary'] = df[df['max_salary'].str.contains('\d', na=False)]['max_salary'].str.replace(' ','',regex=True)

# %%
# for empty values in min and max salary
# let the unknown value equal to the known min/max value 
df.loc[df['min_salary'] == 'unknown','min_salary'] = df['max_salary']
df.loc[df['max_salary'] == 'unknown','max_salary'] = df['min_salary']

# %%
# convert all salary into annual rate using
# first convert all data into specific data type 
df['min_salary'] = df['min_salary'].astype('float32')
df['max_salary'] = df['max_salary'].astype('float32')

# %%
df.loc[df['min_salary'] < 50 , 'min_salary'] = df['min_salary']*8*200
df.loc[df['max_salary'] < 50 , 'max_salary'] = df['max_salary']*8*200

# %%
df
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                               1  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...
